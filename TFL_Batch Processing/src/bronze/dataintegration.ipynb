# %%
import psycopg2
connection = psycopg2.connect(
        host="18.134.163.221",
        database="testdb",
        user="Consultants",
        password="WelcomeItc@2022",
        port="5432"
    )
cursor = connection.cursor()
print("DB connected successfully")
# Out:
# DB connected successfully

# %%
import pandas as pd
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# base path to raw CSVs
base_path = "../../data/raw"

# Encode password
password = quote_plus("WelcomeItc@2022")

# Read Victoria_lines
victoria_lines = pd.read_csv(f"{base_path}/Victoria.csv")
victoria_lines.head()

# Connect to DB
engine = create_engine(f'postgresql+psycopg2://Consultants:{password}@18.134.163.221:5432/testdb')
print("DB connected successfully")
 
# Append data to table
victoria_lines.to_sql('TFL_victoria_lines', engine, if_exists='append', index=False)
# Out:
# DB connected successfully
# 549

# %%
# Read Bakerloo_lines
bakerloo_lines = pd.read_csv(f"{base_path}/Bakerloo.csv")
bakerloo_lines.head()

# Connect to DB
engine = create_engine(f'postgresql+psycopg2://Consultants:{password}@18.134.163.221:5432/testdb')
print("DB connected successfully")
 
# Append data to table
bakerloo_lines.to_sql('TFL_bakerloo_lines', engine, if_exists='append', index=False)
# Out:
# DB connected successfully
# 577

# %%
# Read Central_lines
central_lines = pd.read_csv(f"{base_path}/Central.csv")
central_lines.head()

# Connect to DB
engine = create_engine(f'postgresql+psycopg2://Consultants:{password}@18.134.163.221:5432/testdb')
print("DB connected successfully")
 
# Append data to table
central_lines.to_sql('tfl_central_lines', engine, if_exists='append', index=False)
# Out:
# DB connected successfully
# 547

# %%
# Read metropolitan_lines
metropolitan_lines = pd.read_csv(f"{base_path}/Metropolitan.csv")
metropolitan_lines.head()

# Connect to DB
engine = create_engine(f'postgresql+psycopg2://Consultants:{password}@18.134.163.221:5432/testdb')
print("DB connected successfully")
 
# Append data to table
metropolitan_lines.to_sql('TFL_metropolitan_lines', engine, if_exists='append', index=False)
# Out:
# DB connected successfully
# 362

# %%
# Read northern_lines
northern_lines = pd.read_csv(f"{base_path}/Northern.csv")
northern_lines.head()

# Connect to DB
engine = create_engine(f'postgresql+psycopg2://Consultants:{password}@18.134.163.221:5432/testdb')
print("DB connected successfully")
 
# Append data to table
northern_lines.to_sql('TFL_northern_lines', engine, if_exists='append', index=False)
# Out:
# DB connected successfully
# 65

# %%
# Read piccadilly_lines
piccadilly_lines = pd.read_csv(f"{base_path}/Piccadilly.csv")
piccadilly_lines.head()

# Connect to DB
engine = create_engine(f'postgresql+psycopg2://Consultants:{password}@18.134.163.221:5432/testdb')
print("DB connected successfully")
 
# Append data to table
piccadilly_lines.to_sql('TFL_piccadilly_lines', engine, if_exists='append', index=False)
# Out:
# DB connected successfully
# 952
